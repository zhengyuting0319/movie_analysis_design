# %%
#!/usr/bin/env python3
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
#读取工作簿和工作簿中的工作表
data = pd.read_excel(io='movie_data.xlsx')
plt.scatter(data.Metascore, data.total_gross)
plt.show()

# %%
import numpy as np
plt.scatter(np.log(np.log(data.budget_millions)), data.total_gross)
plt.show()
